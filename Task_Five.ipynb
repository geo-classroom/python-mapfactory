# %%
! pip install folium matplotlib mapclassify
import folium
import json
import seaborn as sns
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt

# %%
#Add  to geojson map dataframe
df = gpd.read_file('C:/Users/HP/Desktop/GMT 320/Joyce/country_boundaries_v2.json')
df
# Out:
#                       SOVEREIGNT               TYPE  \
# 0                           Fiji  Sovereign country
# 1    United Republic of Tanzania  Sovereign country
# 2                 Western Sahara      Indeterminate
# 3                         Canada  Sovereign country
# 4       United States of America            Country
# ..                           ...                ...
# 172           Republic of Serbia  Sovereign country
# 173                   Montenegro  Sovereign country
# 174                       Kosovo           Disputed
# 175          Trinidad and Tobago  Sovereign country
# 176                  South Sudan  Sovereign country
#
#                            ADMIN                      NAME  \
# 0                           Fiji                      Fiji
# 1    United Republic of Tanzania                  Tanzania
# 2                 Western Sahara                 W. Sahara
# 3                         Canada                    Canada
# ...

# %%
#function to create choropleth map
#Define map properties
column='POP_EST'
k_classes=5
scheme="quantiles"
cmap = 'Dark2'
figsize=(20,20)

#Create function for choropleth map with 7 classes
def choropleth( df,column,scheme,cmap,figsize):
    map = df.plot( column=column, scheme=scheme,legend=True,cmap = 'Dark2',k=k_classes,figsize=(20,20))
    return map
#Call the function
choropleth(df,column,scheme,cmap,figsize)
# Out:
# <AxesSubplot:>
