# %%
! pip install folium matplotlib mapclassify
import folium
import json
import seaborn as sns
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from shapely.geometry import Point, Polygon

# %%
#  Import ports shapefile
fp="C:/Users/HP/Desktop/GMT 320/Joyce/ne_10m_ports.shp"
port = gpd.read_file(fp)
port
# Out:
#       scalerank featurecla                          name  \
# 0             8       Port                 Sint Nicolaas
# 1             8       Port                       Campana
# 2             8       Port                        Zarate
# 3             8       Port  Puerto Belgrano/Bahia Blanca
# 4             8       Port    Puerto Galvan/Bahia Blanca
# ...         ...        ...                           ...
# 1076          3       Port                       Norfolk
# 1077          3       Port                       Seattle
# 1078          3       Port                     Cape Town
# 1079          3       Port                       Toronto
# 1080          3       Port                       Chicago
#
#                                      website  natlscale       ne_id  \
# 0            www.rocargo.com/SanNicolas.html        5.0  1730087247
# 1                www.consejoportuario.com.ar        5.0  1730087249
# 2                www.consejoportuario.com.ar        5.0  1730087251
# ...

# %%
#Function to create proportional symbol using points
#define function properties
column ='scalerank'
df=port
def pointsize( df,column):
    map = port.plot( column=column,markersize=port['scalerank'],legend=True)
    return map
#Call the function
pointsize(df,column)
# Out:
# <AxesSubplot:>
