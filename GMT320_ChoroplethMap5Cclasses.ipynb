# %%
# %pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\ramoraswi\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\ramoraswi\anaconda3\lib\site-packages (from geopandas) (3.4.0)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: packaging in c:\users\ramoraswi\anaconda3\lib\site-packages (from geopandas) (21.0)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\ramoraswi\anaconda3\lib\site-packages (from geopandas) (1.3.4)
# Requirement already satisfied: fiona>=1.8 in c:\users\ramoraswi\anaconda3\lib\site-packages (from geopandas) (1.8.22)
# Requirement already satisfied: shapely<2,>=1.7 in c:\users\ramoraswi\anaconda3\lib\site-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: attrs>=17 in c:\users\ramoraswi\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: munch in c:\users\ramoraswi\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in c:\users\ramoraswi\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (58.0.4)
# Requirement already satisfied: certifi in c:\users\ramoraswi\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.7 in c:\users\ramoraswi\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\ramoraswi\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click>=4.0 in c:\users\ramoraswi\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (8.0.3)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\ramoraswi\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: colorama in c:\users\ramoraswi\anaconda3\lib\site-packages (from click>=4.0->fiona>=1.8->geopandas) (0.4.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ramoraswi\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ramoraswi\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ramoraswi\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (1.20.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\ramoraswi\anaconda3\lib\site-packages (from packaging->geopandas) (3.0.4)

# %%
#import libraries
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
url = (r'C:\Users\Ramoraswi\Downloads\country_boundaries_v2.json')
geoJson = gpd.read_file(url)
geoJson
# Out:
#                       SOVEREIGNT               TYPE  \
# 0                           Fiji  Sovereign country
# 1    United Republic of Tanzania  Sovereign country
# 2                 Western Sahara      Indeterminate
# 3                         Canada  Sovereign country
# 4       United States of America            Country
# ..                           ...                ...
# 172           Republic of Serbia  Sovereign country
# 173                   Montenegro  Sovereign country
# 174                       Kosovo           Disputed
# 175          Trinidad and Tobago  Sovereign country
# 176                  South Sudan  Sovereign country
#
#                            ADMIN                      NAME  \
# 0                           Fiji                      Fiji
# 1    United Republic of Tanzania                  Tanzania
# 2                 Western Sahara                 W. Sahara
# 3                         Canada                    Canada
# 4       United States of America  United States of America
# ..                           ...                       ...
# 172           Republic of Serbia                    Serbia
# 173                   Montenegro                Montenegro
# 174                       Kosovo                    Kosovo
# 175          Trinidad and Tobago       Trinidad and Tobago
# 176                  South Sudan                  S. Sudan
#
#                NAME_LONG                         FORMAL_EN      POP_EST  \
# 0                   Fiji                  Republic of Fiji     889953.0
# 1               Tanzania       United Republic of Tanzania   58005463.0
# 2         Western Sahara  Sahrawi Arab Democratic Republic     603253.0
# 3                 Canada                            Canada   37589262.0
# 4          United States          United States of America  328239523.0
# ..                   ...                               ...          ...
# 172               Serbia                Republic of Serbia    6944975.0
# 173           Montenegro                        Montenegro     622137.0
# 174               Kosovo                Republic of Kosovo    1794248.0
# 175  Trinidad and Tobago   Republic of Trinidad and Tobago    1394973.0
# 176          South Sudan           Republic of South Sudan   11062113.0
#
#      POP_RANK                    ECONOMY               INCOME_GRP  \
# 0          11       6. Developing region   4. Lower middle income
# 1          16  7. Least developed region            5. Low income
# 2          11  7. Least developed region            5. Low income
# 3          15    1. Developed region: G7     1. High income: OECD
# 4          17    1. Developed region: G7     1. High income: OECD
# ..        ...                        ...                      ...
# 172        13       6. Developing region   3. Upper middle income
# 173        11       6. Developing region   3. Upper middle income
# 174        12       6. Developing region   4. Lower middle income
# 175        12       6. Developing region  2. High income: nonOECD
# 176        14  7. Least developed region            5. Low income
#
#          CONTINENT         SUBREGION                   REGION_WB     LABEL_X  \
# 0          Oceania         Melanesia         East Asia & Pacific  177.975427
# 1           Africa    Eastern Africa          Sub-Saharan Africa   34.959183
# 2           Africa   Northern Africa  Middle East & North Africa  -12.630304
# 3    North America  Northern America               North America -101.910700
# 4    North America  Northern America               North America  -97.482602
# ..             ...               ...                         ...         ...
# 172         Europe   Southern Europe       Europe & Central Asia   20.787989
# 173         Europe   Southern Europe       Europe & Central Asia   19.143727
# 174         Europe   Southern Europe       Europe & Central Asia   20.860719
# 175  North America         Caribbean   Latin America & Caribbean  -60.918400
# 176         Africa    Eastern Africa          Sub-Saharan Africa   30.390151
#
#        LABEL_Y                                           geometry
# 0   -17.826099  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    -6.051866  MULTIPOLYGON (((33.90371 -0.95000, 34.07262 -1...
# 2    23.967592  MULTIPOLYGON (((-8.66559 27.65643, -8.66512 27...
# 3    60.324287  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    39.538479  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..         ...                                                ...
# 172  44.189919  MULTIPOLYGON (((18.82982 45.90887, 18.82984 45...
# 173  42.803101  MULTIPOLYGON (((20.07070 42.58863, 19.80161 42...
# 174  42.593587  MULTIPOLYGON (((20.59025 41.85541, 20.52295 42...
# 175  10.998900  MULTIPOLYGON (((-61.68000 10.76000, -61.10500 ...
# 176   7.230477  MULTIPOLYGON (((30.83385 3.50917, 29.95350 4.1...
#
# [177 rows x 16 columns]

# %%
def population_class(population):
    if population['POP_EST'] >= 600000000:
        return '1. Extremely High'
    elif population['POP_EST'] >= 50000000 and population['POP_EST'] < 600000000:
        return '2. High'
    elif population['POP_EST'] >= 9000000 and population['POP_EST'] < 50000000:
        return '3. Average'
    elif population['POP_EST'] >= 1000000 and population['POP_EST'] < 9000000:
        return '4. Low'
    elif population['POP_EST'] >= 900000:
        return '5. Extremely Low'

# %%
geoJson['population_class'] = geoJson.apply(lambda population: population_class(population), axis= 1)
geoJson
Map = geoJson.plot(column = 'population_class',legend = True, cmap ='YlGn')
Map
# Out:
# <AxesSubplot:>

# %%
geoJson['POP_EST'].max()
# Out:
# 1397715000.0

# %%
geoJson['POP_EST'].min()
# Out:
# 140.0
