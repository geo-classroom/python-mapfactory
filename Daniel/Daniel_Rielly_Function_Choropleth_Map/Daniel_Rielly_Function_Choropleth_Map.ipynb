# %% [markdown]
# Import the required libraries And the pandas dataframe

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import mapclassify
pd.options.display.max_rows=10

# %% [markdown]
# Import the country boundaries data

# %%
countries = geopandas.read_file(r'C:\Users\riell\OneDrive\Desktop\Countries\country_boundaries_v2.json')

# %% [markdown]
# Visualise the .json data attribute table

# %%
countries
# Out:
#                       SOVEREIGNT               TYPE  \
# 0                           Fiji  Sovereign country
# 1    United Republic of Tanzania  Sovereign country
# 2                 Western Sahara      Indeterminate
# 3                         Canada  Sovereign country
# 4       United States of America            Country
# ..                           ...                ...
# 172           Republic of Serbia  Sovereign country
# 173                   Montenegro  Sovereign country
# 174                       Kosovo           Disputed
# 175          Trinidad and Tobago  Sovereign country
# 176                  South Sudan  Sovereign country
#
#                            ADMIN                      NAME  \
# 0                           Fiji                      Fiji
# 1    United Republic of Tanzania                  Tanzania
# 2                 Western Sahara                 W. Sahara
# 3                         Canada                    Canada
# ...

# %% [markdown]
# Visualise the data as a basic map

# %%
countries.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Create a chloropleth map:
#
# Define the size, width, colour and aspect characteristics
# =-9
# n=u
# Define and plot the population "POP_EST" column
#
# Define the scheme as 6 class quantiles interval
#
# Define the legend and map title

# %%
fig, ax = plt.subplots(figsize=(15,10),subplot_kw=dict(aspect='equal'))
countries.plot(column= 'POP_EST', scheme='Quantiles', k= 6, cmap='YlGn', legend=True, ax=ax,
              legend_kwds{'label':"Population by Country"})
ax.set_title('Population - 6 classes using quantiles', size=18, weight='bold')
ax.axis('off')
# Out:
# (-197.99999999999997, 198.0, -98.6822565, 92.3273865)
